# %%
from PIL import Image

# %%
i = Image.open('15033649_10211078424907271_533264582_n.jpg')
i2 = np.array(i)
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F67D0351DA0>

# %%
import skimage.morphology as mor

# %%
# %matplotlib inline
plt.imshow(mor.skeletonize((i2//255)[:,:,0])//255)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-b50cc9a81de3> in <module>()
#       1 get_ipython().magic('matplotlib inline')
# ----> 2 plt.imshow(mor.skeletonize(i2[:,:,0])//255)
#
# /usr/lib/python3.5/site-packages/skimage/morphology/_skeletonize.py in skeletonize(image)
#      91         raise ValueError('Skeletonize requires a 2D array')
#      92     if not np.all(np.in1d(image.flat, (0, 1))):
# ---> 93         raise ValueError('Image contains values other than 0 and 1')
#      94
#      95     return _fast_skeletonize(image)
#
# ValueError: Image contains values other than 0 and 1

# %%
set(list((i2//255).flatten()))
# Out:
# {0, 1}
